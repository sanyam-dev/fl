# %%
import warnings
warnings.filterwarnings('ignore')

#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model	import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
dataset = pd.read_csv("sklearn-logreg-mnist/dataset/textdatamy.csv")
dataset
# Out:
#         Unnamed: 0  Smoking  SkinCancer  AlcoholDrinking  Stroke  DiffWalking  \
# 0                0        1           1                0       0            0
# 1                1        0           0                0       1            0
# 2                2        1           0                0       0            0
# 3                3        0           1                0       0            0
# 4                4        0           0                0       0            1
# ...            ...      ...         ...              ...     ...          ...
# 319790      319790        1           0                0       0            1
# 319791      319791        1           0                0       0            0
# 319792      319792        0           0                0       0            0
# 319793      319793        0           0                0       0            0
# 319794      319794        0           0                0       0            0
#
#         Sex  PhysicalActivity  Asthma  KidneyDisease  HeartDisease
# 0         1                 1       1              0             0
# 1         1                 1       0              0             0
# 2         0                 1       1              0             0
# 3         1                 0       0              0             0
# 4         1                 1       0              0             0
# ...     ...               ...     ...            ...           ...
# 319790    0                 0       1              0             1
# 319791    0                 1       1              0             0
# 319792    1                 1       0              0             0
# 319793    1                 0       0              0             0
# 319794    1                 1       0              0             0
#
# [319795 rows x 11 columns]

# %%
X= dataset.iloc[:,1: -1].values 
Y= dataset.iloc[:, 10].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.20)
scaler= StandardScaler()
scaler.fit(X_train)
X_train= scaler.transform(X_train)
X_test= scaler.transform(X_test)
# classifier= KNeighborsClassifier(n_neighbors=5)
classifier = LogisticRegression()
classifier.fit(X_train,Y_train)
Y_pred=classifier.predict(X_test)
print(classification_report(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     58514
#            1       0.54      0.07      0.13      5445
#
#     accuracy                           0.92     63959
#    macro avg       0.73      0.53      0.54     63959
# weighted avg       0.89      0.92      0.89     63959
#
# [[58173   341]
#  [ 5050   395]]
